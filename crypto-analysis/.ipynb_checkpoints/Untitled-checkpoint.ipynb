# %%
####################################
#  Author : Bastien Girardet
#  Goal : Fetch historical data for each cryptocurrencies in our dataset
#         To assess the performance of each.
#  Date : 05-09-2019
####################################

# We import the required libraries
import os
import re
import pandas as pd 
from datetime import datetime
from Cryptocurrency import Cryptocurrency

# We get the list of cryptocurrencies
df_crypto_meta = pd.read_csv("./data/crypto.csv")
crypto_dict = {}


# We gather the data for each crypto in our crypto dataset
for idx, crypto in df_crypto_meta.iterrows():
    print("Retrieve crypto_data...")
    data = pd.read_csv(f"./data/crypto-ohlc/{crypto['filename']}")
    data = data.iloc[:,1:len(data['Date'])]
    crypto_dict[crypto['symbol']] = Cryptocurrency(crypto['name'], data= data )
    print("Done...")
# Out:
# Retrieve crypto_data...
# Computing overnight trading...
# Done !
# Computing daily volatility
# Done !
# /home/bgir/projects/swissborg/crypto-analysis/Cryptocurrency.py:153: RuntimeWarning: invalid value encountered in log
#   self.data['log_return'] = np.log(self.data['returns']*100)
# Computing RSI...
# Done !
# Computing momentum...
# Done !
# Computing Stochastic K...
# /home/bgir/projects/swissborg/crypto-analysis/Cryptocurrency.py:315: RuntimeWarning: divide by zero encountered in double_scalars
#   RS = avg_up / avg_down
# /home/bgir/projects/swissborg/crypto-analysis/Cryptocurrency.py:315: RuntimeWarning: invalid value encountered in double_scalars
#   RS = avg_up / avg_down
# Done !
# Done...
# Retrieve crypto_data...
# Computing overnight trading...
# Done !
# Computing daily volatility
# Done !
# /home/bgir/projects/swissborg/crypto-analysis/Cryptocurrency.py:153: RuntimeWarning: divide by zero encountered in log
#   self.data['log_return'] = np.log(self.data['returns']*100)
# Computing RSI...
# Done !
# Computing momentum...
# Done !
# Computing Stochastic K...
# Done !
# Done...
# Retrieve crypto_data...
# Computing overnight trading...
# Done !
# Computing daily volatility
# Done !
# Computing RSI...
# Done !
# Computing momentum...
# Done !
# Computing Stochastic K...
# Done !
# Done...
# Retrieve crypto_data...
# Computing overnight trading...
# Done !
# Computing daily volatility
# Done !
# Computing RSI...
# Done !
# Computing momentum...
# Done !
# Computing Stochastic K...
# Done !
# Done...
# Retrieve crypto_data...
# Computing overnight trading...
# Done !
# Computing daily volatility
# Done !
# Computing RSI...
# Done !
# Computing momentum...
# Done !
# Computing Stochastic K...
# Done !
# Done...
# Retrieve crypto_data...
# Computing overnight trading...
# Done !
# Computing daily volatility
# Done !
# Computing RSI...
# Done !
# Computing momentum...
# Done !
# Computing Stochastic K...
# Done !
# Done...
# Retrieve crypto_data...
# Computing overnight trading...
# Done !
# Computing daily volatility
# Done !
# Computing RSI...
# Done !
# Computing momentum...
# Done !
# Computing Stochastic K...
# Done !
# Done...

# %%
crypto_dict['CHSB'].data.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'volume', 'market_cap', 'is_win', 'pos',
#        'idx', 'open_close', 'candle_body_value', 'upper_candle_value',
#        'lower_candle_value', 'max_diff', 'upper_leg_on_max_diff_ratio',
#        'lower_leg_on_max_diff_ratio', 'body_to_upper_leg_ratio',
#        'body_to_lower_leg_ratio', 'body_to_max_diff_ratio', 'lagged_open',
#        'lagged_close', 'returns', 'log_return', 'overnight_trading',
#        'daily_volatility', 'daily_ann_volatility', 'HV_10_days', 'DHV_10_days',
#        'DMA_HV_10_days', 'DMA_DHV_10_days', 'SMA_10_days',
#        'DSMA_10_days_5_days_shift', 'EMA_10_days', 'up', 'down', 'RSI',
#        'momentum', 'boll_bands_upper_band', 'boll_bands_lower_band',
#        'stochastic_k', 'stochastic_d', 'R%'],
#       dtype='object')

# %%
crypto_dict['CHSB'].data[['boll_bands_upper_band','boll_bands_lower_band','close']].plot()

# %%
crypto_dict['CHSB'].data[['market_cap']].plot()

# %%
def plot_crypto(name,colname,data,log=False, standardize = False, bollinger=False, SMA = False):
    """Plot the colname depending on their 
    
    Args:
        name (string) : Name of the crypto used for visualization
        colname (string) : Column of interest
        data (pandas.DataFrame) : Dataframe containing the cryptocurrency data.
        log (boolean) : If logaritmic scale
        standardize (boolean) : If standardized
        bollinger (boolean) : If bollinger
        SMA (boolean) : If SMA
    
    Return: 
        plot the desired graph
    """
    # Import the libraries
    import matplotlib.pyplot as plt
    import numpy as np
        
    # Define the fig as so
    fig, ax = plt.subplots(figsize=(30,10))
       
    # If logarithmic scale   
    if log:    
        x = np.log(data[[colname]])
    else:
        x = data[[colname]]
    
    # If standardization
    if standardize: 
        mean = data[[colname]].mean()
        std = data[[colname]].std()
        x = data[[colname]]
        x = (x - mean)/std
    else:
        x = data[[colname]]
    
    # We plot
    ax.plot(data.index,x)
    
    # If bollinger bands
    if bollinger:
        ax.plot(data.index,data['boll_bands_lower_band'])
        ax.plot(data.index,data['boll_bands_upper_band'])
    
    label = colname
    
    # Label if log
    if log:
        label += "log scale"
        
    # Label if log
    if standardize:
        label += "standardized"

    ax.set(xlabel='(t) Date', ylabel=label,
           title=f'{name} Analysis of {colname} - (2019-01 / 2019-09)')
    
    ax.legend(name)
    ax.grid()
    
    if log:
        fig.savefig(f"./figs/{name}-{colname}-log-analysis.png")
    else:
        fig.savefig(f"./figs/{name}-{colname}-analysis.png")
        
    plt.show()

# %%
analyse_crypto('CHSB','close',crypto_dict['CHSB'].data, standardize=False, bollinger=True)

# %%
def compare_crypto(colname,crypto_dict,log=False, standardize = False):
    """Compare all the crypto contained in the crypto_dict in the specific column
    
    Args:
        colname (string) : Column of interest
        crypto_dict (dictionnary) : Dictionnary containing Cryptocurrency objects
        log (boolean) : If logaritmic scale
    
    Return: 
        plot containing the comparison
    """
    
    import matplotlib.pyplot as plt
    import numpy as np
    
    label_list = []
    fig, ax = plt.subplots(figsize=(30,10))

    for each in crypto_dict.items():
        try :     
            
            x = each[1].data[[colname]]
            
            if log:    
                x = np.log(each[1].data[[colname]])             
                
            if standardize: 
                mean = each[1].data[[colname]].mean()
                std = each[1].data[[colname]].std()
                x = each[1].data[[colname]]
                x = (x - mean)/std
                
            ax.plot(each[1].data.index,x)
            label_list.append(each[0])
        except:
            print(f"An error occured at {each[0]}")
            print(f"{colname} unkown for {each[0]}")
            
    label = colname

    # Label if log
    if log:
        label += "log scale"

    # Label if log
    if standardize:
        label += "standardized"
                
    ax.set(xlabel='(t) Date', ylabel=label,
           title=f"Comparison of {colname} - (2019-01 / 2019-09)")
    ax.legend(label_list)
    ax.grid()
    if log:
        fig.savefig(f"./figs/{colname}-log-comparison.png")
    else:
        fig.savefig(f"./figs/{colname}-comparison.png")
        
    plt.show()

# %%
compare_crypto('daily_volatility',crypto_dict, log=False, standardize=True)

# %%
compare_crypto('close',crypto_dict, log=False, standardize=True)

# %%
P_0 = crypto_dict['EDO'].data['close'].tail(1)[0] # 100

# %%
P_n = crypto_dict['EDO'].data['close'].head(1)[0] # 200

# %%
r_t = (P_n - P_0) / P_0 * 100

# %%
r_t
# Out:
# -64.31195259919076

# %%
print(P_0 * (1+(r_t/100)))
P_n
# Out:
# 0.28718600000000005
# 0.287186

# %%
crypto_dict['CHSB'].data['close'].tail(1)# 200
# Out:
# Date
# 2019-01-01    0.005972
# Name: close, dtype: float64

# %%
crypto_dict['EDO'].data['close'].plot()

# %%
P_0 * 2.12
# Out:
# 1.70598944

# %%
len(crypto_dict['EDO'].data['up'].iloc[100:114][crypto_dict['EDO'].data['up'].iloc[100:114] != 0])
# Out:
# 6

# %%
len(crypto_dict['EDO'].data['down'].iloc[100:114][crypto_dict['EDO'].data['down'].iloc[100:114] != 0])
# Out:
# 8

# %%
np.sum(crypto_dict['EDO'].data['up'].iloc[100:114][crypto_dict['EDO'].data['up'].iloc[100:114] != 0])/14
# Out:
# 0.013785714285714287

# %%
crypto_dict['EDO'].data['down'].iloc[100:114]
# Out:
# Date
# 2019-05-28    0.000
# 2019-05-27    0.144
# 2019-05-26    0.000
# 2019-05-25    0.016
# 2019-05-24    0.101
# 2019-05-23    0.042
# 2019-05-22    0.000
# 2019-05-21    0.023
# 2019-05-20    0.000
# 2019-05-19    0.087
# 2019-05-18    0.000
# 2019-05-17    0.034
# 2019-05-16    0.000
# 2019-05-15    0.078
# Name: down, dtype: float64

# %%
crypto_dict['EDO'].data['close'].iloc[100:114]
# Out:
# Date
# 2019-05-28    0.916915
# 2019-05-27    0.991918
# 2019-05-26    0.847456
# 2019-05-25    0.868383
# 2019-05-24    0.852162
# 2019-05-23    0.750955
# 2019-05-22    0.708939
# 2019-05-21    0.721345
# 2019-05-20    0.698771
# 2019-05-19    0.713125
# 2019-05-18    0.625848
# 2019-05-17    0.648173
# 2019-05-16    0.614230
# 2019-05-15    0.662809
# Name: close, dtype: float64
