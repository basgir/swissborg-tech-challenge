# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
from os.path import isfile, join
import re
from datetime import datetime
# %matplotlib inline

# %%
mypath = "./snapshots/"

# %%
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
df_files = pd.DataFrame({"filename" : onlyfiles})

currency_per_snapshots = []
num_crypto_per_snapshot= []
timestamps = []
is_swissborg_in = []

for idx, row in df_files.iterrows():
    data = pd.read_csv(join(mypath, row['filename']))
    if len(data[data['Symbol'] == 'CHSB']) > 0:
        is_swissborg_in.append(True)
    else:
        is_swissborg_in.append(False)
    date_time = re.findall("[0-9]{8}",row['filename'])[0]
    num_crypto_per_snapshot.append(len(data)) 
    timestamps.append(date_time)

df_files.index = pd.to_datetime(timestamps, format="%Y%m%d")
df_files['num_crypto'] = pd.to_numeric(num_crypto_per_snapshot)
df_files['is_swissborg_in'] = is_swissborg_in
df_files.sort_index(inplace=True)

# %%
swissborg_introduction = df_files[df_files['is_swissborg_in'] == True].head(1).index.values[0]

# %%
fig, ax = plt.subplots()
ax.plot(df_files.index, df_files['num_crypto'])

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='Cryptocurrencies number evolution (2013-2019)')
ax.grid()
ax.vlines(swissborg_introduction, ymin = 0, ymax = max(df_files['num_crypto']),color="red",label="Swissborg introduction")

fig.savefig("test.png")
plt.show()

# %%
snapshots_data = pd.read_csv("./list.csv")

# %%
snapshots_data.index = pd.to_datetime(snapshots_data['snapshots_date'])

# %%
snapshots_data.drop(labels=['Unnamed: 0','Unnamed: 0.1', 'snapshots_date'],axis=1, inplace=True)

# %%
subperiod = snapshots_data[snapshots_data.index >= "2017-01-01"]


fig, ax = plt.subplots()
ax.plot(subperiod.index, subperiod['total_cap'])

ax.set(xlabel='time (s)', ylabel='In billions of dollars',
       title='Cryptocurrencies market capitalisation (2013-2019)')
ax.grid()
ax.vlines(swissborg_introduction, ymin = 0, ymax = max(subperiod['total_cap']),color="red",label="Swissborg introduction")

fig.savefig("test.png")
plt.show()

# %%
subperiod[subperiod['total_cap'] == max(subperiod['total_cap'])]
# Out:
#                                                  snapshots_url  snapshots  \
# snapshots_date
# 2018-01-07      https://coinmarketcap.com/historical/20180107/   20180107
#
#                    total_cap
# snapshots_date
# 2018-01-07      8.305955e+11

# %%
BTC_subperiod = pd.read_html("https://coinmarketcap.com/currencies/bitcoin/historical-data/?start=20170101&end=20190905")[0]

# %%
BTC_subperiod.index = pd.to_datetime(BTC_subperiod['Date'])

# %%
subperiod
# Out:
#                                                  snapshots_url  snapshots  \
# snapshots_date
# 2017-01-01      https://coinmarketcap.com/historical/20170101/   20170101
# 2017-01-08      https://coinmarketcap.com/historical/20170108/   20170108
# 2017-01-15      https://coinmarketcap.com/historical/20170115/   20170115
# 2017-01-22      https://coinmarketcap.com/historical/20170122/   20170122
# 2017-01-29      https://coinmarketcap.com/historical/20170129/   20170129
# 2017-02-05      https://coinmarketcap.com/historical/20170205/   20170205
# 2017-02-12      https://coinmarketcap.com/historical/20170212/   20170212
# 2017-02-19      https://coinmarketcap.com/historical/20170219/   20170219
# 2017-02-26      https://coinmarketcap.com/historical/20170226/   20170226
# 2017-03-05      https://coinmarketcap.com/historical/20170305/   20170305
# 2017-03-12      https://coinmarketcap.com/historical/20170312/   20170312
# 2017-03-19      https://coinmarketcap.com/historical/20170319/   20170319
# 2017-03-26      https://coinmarketcap.com/historical/20170326/   20170326
# 2017-04-02      https://coinmarketcap.com/historical/20170402/   20170402
# 2017-04-09      https://coinmarketcap.com/historical/20170409/   20170409
# 2017-04-16      https://coinmarketcap.com/historical/20170416/   20170416
# 2017-04-23      https://coinmarketcap.com/historical/20170423/   20170423
# 2017-04-16      2.877691e+10
# 2017-04-23      2.947396e+10
# 2017-04-30      3.683650e+10
# 2017-05-07      4.843004e+10
# 2017-05-14      5.511089e+10
# 2017-05-21      7.377432e+10
# 2017-05-28      7.252306e+10
# 2017-06-04      9.289687e+10
# 2017-06-11      1.124373e+11
# 2017-06-18      1.103818e+11
# 2017-06-25      1.053032e+11
# 2017-07-02      9.920397e+10
# 2017-07-09      9.333738e+10
# 2017-07-16      6.661126e+10
# 2017-07-23      9.509186e+10
# ...                      ...
# 2019-02-10      1.230293e+11
# 2019-02-17      1.234429e+11
# 2019-02-24      1.276311e+11
# 2019-03-03      1.296405e+11
# 2019-03-10      1.348022e+11
# 2019-03-17      1.395694e+11
# 2019-03-24      1.401544e+11
# 2019-03-31      1.444233e+11
# 2019-04-07      1.817227e+11
# 2019-04-14      1.759860e+11
# 2019-04-21      1.781081e+11
# 2019-04-28      1.710753e+11
# 2019-05-05      1.835590e+11
# 2019-05-12      2.096770e+11
# 2019-05-19      2.553007e+11
# 2019-05-26      2.678508e+11
# 2019-06-02      2.768255e+11
# 2019-06-09      2.445692e+11
# 2019-06-16      2.812207e+11
# 2019-06-23      3.263865e+11
# 2019-06-30      3.130129e+11
# 2019-07-07      3.283094e+11
# 2019-07-14      2.788062e+11
# 2019-07-21      2.909369e+11
# 2019-07-28      2.658465e+11
# 2019-08-04      2.946334e+11
# 2019-08-11      3.019671e+11
# 2019-08-18      2.734461e+11
# 2019-08-25      2.676736e+11
# 2019-09-01      2.556107e+11
#
# [140 rows x 3 columns]

# %%
    
subperiod.index[subperiod.index == BTC_subperiod.index]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-b6a1665ab76d> in <module>
#       1
# ----> 2 subperiod.index[subperiod.index == BTC_subperiod.index]
#
# ~/venv/data-science/lib/python3.6/site-packages/pandas/core/indexes/datetimelike.py in wrapper(self, other)
#     115                 other = other._values
#     116
# --> 117             result = op(self._data, maybe_unwrap_index(other))
#     118             return result
#     119
#
# ~/venv/data-science/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py in wrapper(self, other)
#     154             return ops.invalid_comparison(self, other, op)
#     155         elif len(other) != len(self):
# --> 156             raise ValueError("Lengths must match")
#     157         else:
#     158             if isinstance(other, list):
#
# ValueError: Lengths must match

# %%
subperiod = subperiod.merge(BTC_subperiod, how='left', on=subperiod.index)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-b4c82ec52e95> in <module>
# ----> 1 subperiod = subperiod.merge(BTC_subperiod, how='left', on=subperiod.index)
#
# ~/venv/data-science/lib/python3.6/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6875                      right_on=right_on, left_index=left_index,
#    6876                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6877                      copy=copy, indicator=indicator, validate=validate)
#    6878
#    6879     def round(self, decimals=0, *args, **kwargs):
#
# ~/venv/data-science/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# ~/venv/data-science/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     527         (self.left_join_keys,
#     528          self.right_join_keys,
# --> 529          self.join_names) = self._get_merge_keys()
#     530
#     531         # validate the merge keys dtypes. We may need to coerce
#
# ~/venv/data-science/lib/python3.6/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#     821                         if rk is not None:
#     822                             right_keys.append(
# --> 823                                 right._get_label_or_level_values(rk))
#     824                             join_names.append(rk)
#     825                         else:
#
# ~/venv/data-science/lib/python3.6/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1695             values = self.axes[axis].get_level_values(key)._values
#    1696         else:
# -> 1697             raise KeyError(key)
#    1698
#    1699         # Check for duplicates
#
# KeyError: DatetimeIndex(['2017-01-01', '2017-01-08', '2017-01-15', '2017-01-22',
#                '2017-01-29', '2017-02-05', '2017-02-12', '2017-02-19',
#                '2017-02-26', '2017-03-05',
#                ...
#                '2019-06-30', '2019-07-07', '2019-07-14', '2019-07-21',
#                '2019-07-28', '2019-08-04', '2019-08-11', '2019-08-18',
#                '2019-08-25', '2019-09-01'],
#               dtype='datetime64[ns]', name='snapshots_date', length=140, freq=None)
